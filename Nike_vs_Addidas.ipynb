# %%
import numpy as numpy    # linear algebra
import pandas as pd      # data processing, CSV FILE I/O

# %%
# matplotlib is library for creating static, animated and interactive visualizations
# https://matplotlib.org/stable/tutorials/introductory/pyplot.html
# seaborn gives high-level statistical data visualization
# https://seaborn.pydata.org/tutorial/objects_interface.html

import matplotlib.pyplot as plt  
import seaborn as sns
from pandas import plotting

# %%
import warnings
warnings.filterwarnings('ignore')

#And while I just wrote that you might want to get the user’s attention, I’d argue that most of the time, warnings are 
# aimed at developers rather than users. Warnings in Python are sort of like the “service needed” light on a car; 
# the user might know that something is wrong, but only a qualified repairperson will know what to do. 
# Developers should avoid showing warnings to end users.

# %%
mask = "C:/Users/Dhanush Kenganauar/Downloads/Important_documents/UTD/Projects/Nike_vs_addidas/Adidas_Vs_Nike.csv"
df = pd.read_csv(mask)

# %%
df.head()     # gives the top 5 rows
# Out:
#                                         Product Name Product ID  \
# 0  Women's adidas Originals NMD_Racer Primeknit S...     AH2430
# 1               Women's adidas Originals Sleek Shoes     G27341
# 2                  Women's adidas Swim Puka Slippers     CM0081
# 3   Women's adidas Sport Inspired Questar Ride Shoes     B44832
# 4           Women's adidas Originals Taekwondo Shoes     D98205
#
#    Listing Price  Sale Price  Discount                    Brand  \
# 0          14999        7499        50  Adidas Adidas ORIGINALS
# 1           7599        3799        50         Adidas ORIGINALS
# 2            999         599        40        Adidas CORE / NEO
# 3           6999        3499        50        Adidas CORE / NEO
# 4           7999        3999        50         Adidas ORIGINALS
#
#                                          Description  Rating  Reviews  \
# 0  Channeling the streamlined look of an '80s rac...     4.8       41
# ...

# %%
df.tail()   # gives the bottom 5 rows
# Out:
#                               Product Name  Product ID  Listing Price  \
# 3263                    Air Jordan 8 Retro  CI1236-100          15995
# 3264            Nike Phantom Venom Club IC  AO0578-717           4995
# 3265  Nike Mercurial Superfly 7 Academy TF  AT7978-414           8495
# 3266                       Nike Air Max 98  AH6799-300              0
# 3267                        Nike P-6000 SE  CJ9585-600           8995
#
#       Sale Price  Discount Brand  \
# 3263       12797         0  Nike
# 3264        3497         0  Nike
# 3265        5947         0  Nike
# 3266       16995         0  Nike
# 3267        6297         0  Nike
#
#                                             Description  Rating  Reviews  \
# 3263  The Air Jordan 8 Retro recaptures the memorabl...     5.0        1
# 3264  The Nike Phantom Venom Club IC is engineered f...     0.0        0
# 3265  The soft upper of the Nike Mercurial Superfly ...     5.0        1
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3268 entries, 0 to 3267
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Product Name   3268 non-null   object
#  1   Product ID     3268 non-null   object
#  2   Listing Price  3268 non-null   int64
#  3   Sale Price     3268 non-null   int64
#  4   Discount       3268 non-null   int64
#  5   Brand          3268 non-null   object
#  6   Description    3265 non-null   object
#  7   Rating         3268 non-null   float64
#  8   Reviews        3268 non-null   int64
#  9   Last Visited   3268 non-null   object
# dtypes: float64(1), int64(4), object(5)
# memory usage: 255.4+ KB

# %%
df.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3268 entries, 0 to 3267
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Product Name   3268 non-null   object
#  1   Product ID     3268 non-null   object
#  2   Listing Price  3268 non-null   int64
#  3   Sale Price     3268 non-null   int64
#  4   Discount       3268 non-null   int64
#  5   Brand          3268 non-null   object
#  6   Description    3265 non-null   object
#  7   Rating         3268 non-null   float64
#  8   Reviews        3268 non-null   int64
#  9   Last Visited   3268 non-null   object
# dtypes: float64(1), int64(4), object(5)
# memory usage: 2.1 MB

# %%
df=df.rename(columns=
             {'Product ID': 'Product_ID', 
              'Listing Price': 'Listing_Price',
              'Sale Price':'Sale_Price',
              'Last Visited':'Last_Visited'})

# %%
df['Brand'].unique()
# Out:
# array(['Adidas Adidas ORIGINALS', 'Adidas ORIGINALS', 'Adidas CORE / NEO',
#        'Adidas SPORT PERFORMANCE', 'Nike'], dtype=object)

# %%
df=df.replace('Adidas Adidas ORIGINALS', 'Adidas ORIGINALS')

# %%
df.describe()
# Out:
#        Listing_Price    Sale_Price     Discount       Rating      Reviews
# count    3268.000000   3268.000000  3268.000000  3268.000000  3268.000000
# mean     6868.020196   6134.265606    26.875765     3.242105    40.551714
# std      4724.659386   4293.247581    22.633487     1.428856    31.543491
# min         0.000000    449.000000     0.000000     0.000000     0.000000
# 25%      4299.000000   2999.000000     0.000000     2.600000    10.000000
# 50%      5999.000000   4799.000000    40.000000     3.500000    37.000000
# 75%      8999.000000   7995.000000    50.000000     4.400000    68.000000
# max     29999.000000  36500.000000    60.000000     5.000000   223.000000

# %%
# Let us do brand analysis

# 1. Numbers of each brand in the data

df.groupby('Brand')['Product Name'].count().plot.barh()
# Out:
# <AxesSubplot:ylabel='Brand'>

# %%
# Listing Price by brand
# A Distplot or distribution plot, depicts the variation in the data distribution

# The Seaborn Distplot can also be clubbed along with the Kernel Density Estimate Plot to estimate the probability of 
# distribution of continuous variables across various data values.

#The Rug Plot describes visualizes distribution of data in the form of bins.

plt.figure(figsize=(20,10 ))
sns.distplot(df[df["Brand"]=="Adidas ORIGINALS"].Listing_Price,kde=True,rug=True)
sns.distplot(df[df["Brand"]=="Adidas CORE / NEO"].Listing_Price,kde=True,rug=True)
sns.distplot(df[df["Brand"]=="Adidas SPORT PERFORMANCE"].Listing_Price,kde=True,rug=True)
sns.distplot(df[df["Brand"]=="Nike"].Listing_Price,kde=True,rug=True)
plt.legend(labels=['Adidas ORIGINALS', 'Adidas CORE / NEO','Adidas SPORT PERFORMANCE', 'Nike'])
plt.show()

# %%
# product Id's that have listing_price as 0
df[df['Listing_Price']==0].Product_ID
# Out:
# 2625    CJ1646-600
# 2626    CT4328-101
# 2627    CI3482-200
# 2628    CD0479-200
# 2629    CZ6156-101
#            ...
# 3257    CD2722-001
# 3258    AO4568-600
# 3260    AT6100-606
# 3262    CT9155-063
# 3266    AH6799-300
# Name: Product_ID, Length: 426, dtype: object

# %%
df.groupby('Brand').sum('Listing_Price')
# Out:
#                           Listing_Price  Sale_Price  Discount  Rating  Reviews
# Brand
# Adidas CORE / NEO               5501489     3462112     40330  3791.1    53556
# Adidas ORIGINALS                8916992     6185692     28270  3017.8    44744
# Adidas SPORT PERFORMANCE        5534094     3831582     19230  2027.8    29605
# Nike                            2492115     6567394         0  1758.5     4618

# %%
df[df['Listing_Price']==0].Brand.value_counts()
# Out:
# Nike    426
# Name: Brand, dtype: int64

# %%
# Sales price by Brand

plt.figure(figsize=(20, 10))
sns.distplot(df[df["Brand"]=="Adidas ORIGINALS"].Sale_Price,kde=False,rug=False)
sns.distplot(df[df["Brand"]=="Adidas CORE / NEO"].Sale_Price,kde=False,rug=False)
sns.distplot(df[df["Brand"]=="Adidas SPORT PERFORMANCE"].Sale_Price,kde=False,rug=False)
sns.distplot(df[df["Brand"]=="Nike"].Sale_Price,kde=False,rug=False)
plt.legend(labels=['Adidas ORIGINALS', 'Adidas CORE / NEO','Adidas SPORT PERFORMANCE', 'Nike'])
plt.show()

# %%
#Rating By Brand

plt.figure(figsize=(10, 5))
sns.distplot(df[df["Brand"]=="Adidas ORIGINALS"].Rating,kde=False,rug=False)
sns.distplot(df[df["Brand"]=="Adidas CORE / NEO"].Rating,kde=False,rug=False)
sns.distplot(df[df["Brand"]=="Adidas SPORT PERFORMANCE"].Rating,kde=False,rug=False)
sns.distplot(df[df["Brand"]=="Nike"].Rating,kde=False,rug=False)
plt.legend(labels=['Adidas ORIGINALS', 'Adidas CORE / NEO','Adidas SPORT PERFORMANCE', 'Nike'])
plt.show()

# %%
#Reviews By Brand

plt.figure(figsize=(20, 10))
sns.distplot(df[df["Brand"]=="Adidas ORIGINALS"].Reviews,kde=False,rug=False)
sns.distplot(df[df["Brand"]=="Adidas CORE / NEO"].Reviews,kde=False,rug=False)
sns.distplot(df[df["Brand"]=="Adidas SPORT PERFORMANCE"].Reviews,kde=False,rug=False)
sns.distplot(df[df["Brand"]=="Nike"].Reviews,kde=False,rug=False)
plt.legend(labels=['Adidas ORIGINALS', 'Adidas CORE / NEO','Adidas SPORT PERFORMANCE', 'Nike'])
plt.show()

# %%
# Let us see corelation between No listing price,ratings and reviews for Nike

df_n0 = df[(df['Listing_Price']==0)|(df['Brand']=='Nike')]
df_n0
# Out:
#                               Product Name  Product_ID  Listing_Price  \
# 2625        Nike Air Force 1 '07 Essential  CJ1646-600              0
# 2626                  Nike Air Force 1 '07  CT4328-101              0
# 2627          Nike Air Force 1 Sage Low LX  CI3482-200              0
# 2628                   Nike Air Max Dia SE  CD0479-200              0
# 2629                   Nike Air Max Verona  CZ6156-101              0
# ...                                    ...         ...            ...
# 3263                    Air Jordan 8 Retro  CI1236-100          15995
# 3264            Nike Phantom Venom Club IC  AO0578-717           4995
# 3265  Nike Mercurial Superfly 7 Academy TF  AT7978-414           8495
# 3266                       Nike Air Max 98  AH6799-300              0
# 3267                        Nike P-6000 SE  CJ9585-600           8995
#
#       Sale_Price  Discount Brand  \
# 2625        7495         0  Nike
# 2626        7495         0  Nike
# ...

# %%
sns.pairplot(df_n0)

# %% [markdown]
# Lot of Nike products have no reviews which in turn do not have any Listing Price and No ratings.
# On the other hand, other products of nike get high rating compared to adidas products.
# It seems to me that there is a huge gap between fans and those who are not in Nike brand

# %%
# Let us do Product Analysis

df_sp30=df.sort_values(by='Sale_Price',ascending=False).head(30)    # analyzing top 30 values

sns.barplot(x = 'Sale_Price', y = 'Product Name', data = df_sp30, color = 'red')
# Out:
# <AxesSubplot:xlabel='Sale_Price', ylabel='Product Name'>

# %%
df_sp30
# Out:
#                                            Product Name  Product_ID  \
# 3148                    Nike Air VaporMax Flyknit 2 LXX  AT5673-700
# 2554            Men's adidas Originals ZX 4000 4D Shoes      BD7927
# 2579            Men's adidas Originals ZX 4000 4D Shoes      BD7865
# 1438            Men's adidas Originals ZX 4000 4D Shoes      EF9625
# 1642           Unisex adidas Running Alphaedge 4D Shoes      FV6106
# 1553            Men's adidas Originals ZX 4000 4D Shoes      EF9624
# 1563            Men's adidas Originals ZX 4000 4D Shoes      EF9623
# 2931             Nike Mercurial Superfly 7 Elite MDS FG  BQ5469-703
# 2693              Nike Mercurial Superfly 7 Elite SE FG  CT1099-093
# 3164             Nike Mercurial Superfly 7 Elite MDS FG  BQ5469-703
# 3149              Nike Mercurial Superfly 7 Elite SE FG  CT1099-093
# 1328      Unisex Originals CRAIG GREEN KONTUUR II SHOES      FV7825
# 1326      Unisex Originals CRAIG GREEN KONTUUR II SHOES      FV7826
# ...

# %%
#Top 30 listing price products

df_lp30=df.sort_values(by='Listing_Price',ascending=False).head(30)
sns.barplot(x = 'Listing_Price', y = 'Product Name', data = df_lp30, color = 'green')
# Out:
# <AxesSubplot:xlabel='Listing_Price', ylabel='Product Name'>

# %%
#Correlation between rating and other features
df1=df[['Listing_Price','Sale_Price','Discount','Brand','Rating','Reviews']]

# %%
df1
# Out:
#       Listing_Price  Sale_Price  Discount              Brand  Rating  Reviews
# 0             14999        7499        50   Adidas ORIGINALS     4.8       41
# 1              7599        3799        50   Adidas ORIGINALS     3.3       24
# 2               999         599        40  Adidas CORE / NEO     2.6       37
# 3              6999        3499        50  Adidas CORE / NEO     4.1       35
# 4              7999        3999        50   Adidas ORIGINALS     3.5       72
# ...             ...         ...       ...                ...     ...      ...
# 3263          15995       12797         0               Nike     5.0        1
# 3264           4995        3497         0               Nike     0.0        0
# 3265           8495        5947         0               Nike     5.0        1
# 3266              0       16995         0               Nike     4.0        4
# 3267           8995        6297         0               Nike     0.0        0
#
# [3268 rows x 6 columns]

# %%
df1 = pd.get_dummies(df1)   # .get_dummies is used for categorical data. Look the brand names have been given different 
# column and it shows where the each brand is present.

# %%
df1
# Out:
#       Listing_Price  Sale_Price  Discount  Rating  Reviews  \
# 0             14999        7499        50     4.8       41
# 1              7599        3799        50     3.3       24
# 2               999         599        40     2.6       37
# 3              6999        3499        50     4.1       35
# 4              7999        3999        50     3.5       72
# ...             ...         ...       ...     ...      ...
# 3263          15995       12797         0     5.0        1
# 3264           4995        3497         0     0.0        0
# 3265           8495        5947         0     5.0        1
# 3266              0       16995         0     4.0        4
# 3267           8995        6297         0     0.0        0
#
#       Brand_Adidas CORE / NEO  Brand_Adidas ORIGINALS  \
# 0                           0                       1
# 1                           0                       1
# 2                           1                       0
# ...

# %%
sns.heatmap(df1.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
df1.corr()        # correlation between columns.
# Out:
#                                 Listing_Price  Sale_Price  Discount    Rating  \
# Listing_Price                        1.000000    0.312255  0.125999  0.099764
# Sale_Price                           0.312255    1.000000 -0.594659 -0.042172
# Discount                             0.125999   -0.594659  1.000000  0.081510
# Rating                               0.099764   -0.042172  0.081510  1.000000
# Reviews                              0.161296   -0.240728  0.313591  0.140577
# Brand_Adidas CORE / NEO             -0.291115   -0.504591  0.298897  0.085514
# Brand_Adidas ORIGINALS               0.387674    0.097996  0.116726  0.035369
# Brand_Adidas SPORT PERFORMANCE       0.228683    0.020949  0.102402  0.034766
# Brand_Nike                          -0.313499    0.470347 -0.587783 -0.175734
#
#                                  Reviews  Brand_Adidas CORE / NEO  \
# Listing_Price                   0.161296                -0.291115
# ...

# %%
# Direct correlation between 2 columns will be closer to 1
# Inverse correlation between 2 columns wil be closer to -1

# %%
#clustering

df2=df[['Listing_Price','Sale_Price','Discount','Brand','Rating','Reviews']]

df2=df2.replace({'Adidas ORIGINALS':1, 'Adidas CORE / NEO':2,'Adidas SPORT PERFORMANCE':3,'Nike':4})

# %%
df2
# Out:
#       Listing_Price  Sale_Price  Discount  Brand  Rating  Reviews
# 0             14999        7499        50      1     4.8       41
# 1              7599        3799        50      1     3.3       24
# 2               999         599        40      2     2.6       37
# 3              6999        3499        50      2     4.1       35
# 4              7999        3999        50      1     3.5       72
# ...             ...         ...       ...    ...     ...      ...
# 3263          15995       12797         0      4     5.0        1
# 3264           4995        3497         0      4     0.0        0
# 3265           8495        5947         0      4     5.0        1
# 3266              0       16995         0      4     4.0        4
# 3267           8995        6297         0      4     0.0        0
#
# [3268 rows x 6 columns]

# %%
# individual_clustering_score=[]
# for i in range (1,6):
#     kmeans = KMeans(n_clusters=1, init='random', random_state=10)
#     kmeans.fit(df2)
#     individual_clustering_score.append(kmeans.inertia_)
    
# plt.figure(figsize=(10,5))
# plt.plot(range(1,6),individual_clustering_score)
# plt.show()

# %%
from sklearn.cluster import KMeans

kmeans_model = KMeans(n_clusters=4, random_state=10).fit(df2)

# %%
labels = kmeans_model.labels_

# %%
color_codes = {0:'red', 1:'blue', 2:'black',3:'yellow'}
colors = [color_codes[x] for x in labels]

# %%
plotting.scatter_matrix(df2[df2.columns[1:]], figsize=(15,15), color=colors, alpha=0.8, diagonal='kde')
plt.show()

# %%
df['cluster']=pd.DataFrame(labels)
df_clus=df.groupby(['cluster','Brand'])['Product_ID'].count()
df_clus=df_clus.reset_index()
df_clus
# Out:
#     cluster                     Brand  Product_ID
# 0         0          Adidas ORIGINALS         162
# 1         0  Adidas SPORT PERFORMANCE         139
# 2         0                      Nike          89
# 3         1         Adidas CORE / NEO         995
# 4         1          Adidas ORIGINALS          96
# 5         1  Adidas SPORT PERFORMANCE         236
# 6         1                      Nike          75
# 7         2                      Nike         372
# 8         3         Adidas CORE / NEO         116
# 9         3          Adidas ORIGINALS         650
# 10        3  Adidas SPORT PERFORMANCE         231
# 11        3                      Nike         107

# %%
#Brand, sales price and cluster
plt.figure(figsize=(12, 12))
plt.legend(fontsize=10)
plt.tick_params(labelsize=10)
ax=sns.scatterplot(x=df['Brand'],y=df['Sale_Price'],hue=df['cluster'],size=df['Sale_Price'],data=df,sizes=(1,200))
ax.legend(loc='upper left',bbox_to_anchor=(1,1))
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
#Brand rating and cluster

plt.figure(figsize=(12, 12))
plt.legend(fontsize=10)
plt.tick_params(labelsize=10)
ax=sns.scatterplot(x=df['Brand'],y=df['Rating'],hue=df['cluster'],size=df['Rating'],data=df,sizes=(1,200))
ax.legend(loc='upper left',bbox_to_anchor=(1,1))
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
#Top 200 Sale_Price Product, Sale_Price and cluster

df_sp200=df.sort_values(by='Sale_Price',ascending=False).head(200)

plt.figure(figsize=(12, 12))
plt.legend(fontsize=10)
plt.tick_params(labelsize=10)
ax=sns.scatterplot(x=df_sp200['Product Name'],y=df_sp200['Sale_Price'],hue=df_sp200['cluster'],size=df_sp200['Sale_Price'],data=df_sp200,sizes=(1,200))
plt.xticks(rotation=90)
ax.legend(loc='upper left',bbox_to_anchor=(1,1))
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
#Top 200 Sale_Price Product, Rating and cluster

plt.figure(figsize=(12, 12))
plt.legend(fontsize=10)
plt.tick_params(labelsize=10)
ax=sns.scatterplot(x=df_sp200['Product Name'],y=df_sp200['Rating'],hue=df_sp200['cluster'],size=df_sp200['Rating'],data=df_sp200,sizes=(1,200))
plt.xticks(rotation=90)
ax.legend(loc='upper left',bbox_to_anchor=(1,1))
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
#Lowest 200 Sale_Price Product, Sale_Price and cluster

df_spt200=df.sort_values(by='Sale_Price',ascending=False).tail(200)

plt.figure(figsize=(12, 12))
plt.legend(fontsize=10)
plt.tick_params(labelsize=10)
ax=sns.scatterplot(x=df_spt200['Product Name'],y=df_spt200['Sale_Price'],hue=df_spt200['cluster'],size=df_spt200['Sale_Price'],data=df_spt200,sizes=(1,200))
plt.xticks(rotation=90)
ax.legend(loc='upper left',bbox_to_anchor=(1,1))
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
#Lowest 200 Sale_Price Product, Rating and cluster

plt.figure(figsize=(12, 12))
plt.legend(fontsize=10)
plt.tick_params(labelsize=10)
ax=sns.scatterplot(x=df_spt200['Product Name'],y=df_spt200['Rating'],hue=df_spt200['cluster'],size=df_spt200['Rating'],data=df_spt200,sizes=(1,200))
plt.xticks(rotation=90)
ax.legend(loc='upper left',bbox_to_anchor=(1,1))
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
#Sale_Price plays very important role for cluter. On the other hand, Rating is distributed to each cluster, 
#each Brand and each Product. It means that Price is common index for people to think about shoe Brand, adidas and NIKE.
#But Rating may depend on each preferenace, for example,comfotability.fittness,design etc
